# %% [markdown]
# <a href="https://colab.research.google.com/github/injchernomor/ml-libraries-project/blob/dev/notebooks/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder,LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.preprocessing import OneHotEncoder
from sklearn import model_selection
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score




url = 'https://raw.githubusercontent.com/injchernomor/ml-libraries-project/refs/heads/dev/data-source/data/final_dataset_of_encrypted_words.csv'
df = pd.read_csv(url)
df.head()
# Out:
#   encrypted_word encryption_algorithm
# 0           zrug               сaesar
# 1         deedfb               сaesar
# 2       degxfwru               сaesar
# 3           dedv               сaesar
# 4      dedvhphqw               сaesar

# %%
df.isnull().sum()
# Out:
# encrypted_word          0
# encryption_algorithm    0
# dtype: int64

# %%
df["encryption_algorithm"].value_counts()
# Out:
# encryption_algorithm
# сaesar    42053
# sha256    42053
# Name: count, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(df['encrypted_word'], df['encryption_algorithm'], test_size=0.3)

# %%
encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
Y_test = encoder.fit_transform(Y_test)

# %%
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(df["encrypted_word"])

X_train_Tfidf = Tfidf_vect.transform(X_train)
X_test_Tfidf = Tfidf_vect.transform(X_test)
print(Tfidf_vect.vocabulary_)
# Out:
# {'zrug': 4993, 'dfdghplf': 18, 'dflg': 20, 'dffrxqw': 19, 'dgdg': 22, 'dgh': 24, 'dfw': 21, 'dgglwlrq': 23, 'dgmxvwphqw': 25, 'dgyhuwlvhphqw': 26, 'dhurvro': 27, 'djdpd': 28, 'dluhgdoh': 31, 'djuhhphqw': 29, 'do': 32, 'dlu': 30, 'doe': 33, 'dohfwruld': 35, 'dohald': 34, 'doolhv': 37, 'doob': 36, 'dowkhd': 38, 'dpeurvh': 39, 'dphq': 41, 'dphold': 40, 'dpprqlwh': 43, 'dplu': 42, 'dprxqw': 44, 'dpxvhphqw': 45, 'dqd': 46, 'dqhpld': 47, 'dqjvwurp': 51, 'dqjoh': 49, 'dqjolflcdwlrq': 50, 'dqjholfd': 48, 'dqjxlv': 52, 'dqqd': 53, 'dqqrqd': 54, 'dqvzhu': 55, 'dqw': 56, 'dqwdufwlfd': 57, 'dqwl': 58, 'dsdfkh': 59, 'dssdudwxv': 60, 'dssoh': 61, 'dssurydo': 62, 'dufdgldq': 63, 'dufkhu': 65, 'dufk': 64, 'dujr': 67, 'dujhqwlqh': 66, 'dujxphqw': 68, 'dupb': 70, 'dup': 69, 'duudv': 71, 'duw': 72, 'dvfohsldg': 74, 'dv': 73, 'dvkxu': 76, 'dvfrw': 75, 'dvwhulrq': 77, 'dvwloeh': 78, 'dvwudjdoxv': 79, 'dw': 80, 'dwodqwlf': 81, 'dwodv': 82, 'dwwdfn': 83, 'dwwlf': 86, 'dwwudfwlrq': 87, 'dxfxed': 88, 'dwwhpsw': 84, 'dwwhqwlrq': 85, 'dxn': 90, 'dxjxvw': 89, 'dxulfxod': 91, 'dxulfxoduld': 92, 'dxvwudo': 93, 'dxwkrulwb': 94, 'dxwrjlur': 95, 'dxwrpdwlf': 96, 'dcdohd
, 'fduulcr': 244, 'fduub': 243, 'fduw': 246, 'fduwhu': 247, 'fdvkphuh': 249, 'fdvh': 248, 'fdvvld': 250, 'fdvvlh': 251, 'fduuldjh': 245, 'fdw': 253, 'fdwdosd': 254, 'fdvwru': 252, 'fdwwb': 255, 'fdwwohbd': 256, 'fdxgdwd': 257, 'fdbhqqh': 221, 'fdxvh': 258, 'fhow': 260, 'fhooxorlg': 259, 'fhqwdxuxv': 261, 'fhvwuxp': 262, 'fkdlq': 263, 'fkdon': 264, 'fkdqgl': 266, 'fkdqjh': 268, 'fkdqfh': 265, 'fkdqj': 267, 'fkduwlvw': 269, 'fkdwhdx': 270, 'fkhhvh': 271, 'fkhplfdo': 272, 'fkhvwhu': 274, 'fkhvw': 273, 'fklfndvdz': 275, 'fklfr': 276, 'fklhi': 277, 'fklq': 278, 'fklqn': 279, 'fkls': 280, 'fkxfn': 281, 'fkxufk': 282, 'flufoh': 283, 'flwuxv': 284, 'fodun': 286, 'fodb': 285, 'fohdq': 287, 'fohdu': 288, 'folii': 289, 'forfn': 290, 'forwk': 291, 'forxg': 292, 'frdo ...

# %%
print(X_train_Tfidf)
# Out:
#   (3, 2521)	1.0
#   (4, 1216)	1.0
#   (19, 3065)	1.0
#   (90, 1547)	1.0
#   (105, 4729)	1.0
#   (107, 829)	1.0
#   (130, 1301)	1.0
#   (135, 2350)	1.0
#   (178, 1229)	1.0
#   (191, 1437)	1.0
#   (194, 3489)	1.0
#   (212, 3107)	1.0
#   (218, 2416)	1.0
#   (256, 404)	1.0
#   (258, 4359)	1.0
#   (270, 4993)	1.0
#   (275, 4035)	1.0
#   (292, 823)	1.0
#   (302, 4814)	1.0
#   (314, 3713)	1.0
#   (319, 4240)	1.0
#   (323, 4505)	1.0
#   (329, 7)	1.0
#   (353, 4953)	1.0
#   (363, 1026)	1.0
#   :	:
#   (58529, 1867)	1.0
#   (58567, 2229)	1.0
#   (58584, 4630)	1.0
#   (58593, 3990)	1.0
#   (58610, 1834)	1.0
#   (58626, 2490)	1.0
#   (58634, 1569)	1.0
#   (58652, 1003)	1.0
#   (58665, 1647)	1.0
#   (58669, 4110)	1.0
#   (58676, 1240)	1.0
#   (58677, 3669)	1.0
#   (58691, 3271)	1.0
#   (58715, 18)	1.0
#   (58739, 3783)	1.0
#   (58741, 2246)	1.0
#   (58765, 4299)	1.0
#   (58778, 4038)	1.0
#   (58801, 1210)	1.0
#   (58821, 3099)	1.0
#   (58840, 3643)	1.0
#   (58841, 1896)	1.0
#   (58843, 3377)	1.0
#   (58849, 2591)	1.0
#   (58866, 883)	1.0

# %%
SVM_Model = SVC(gamma='auto')
SVM_Model.fit(X_train_Tfidf,Y_train)
# Out:
# SVC(gamma='auto')

# %%
predictions_SVM = SVM_Model.predict(X_test_Tfidf)
print(f"SVM accuracy score: {accuracy_score(predictions_SVM,Y_test)*100}")
# Out:
# SVM accuracy score:49.7503170577045
